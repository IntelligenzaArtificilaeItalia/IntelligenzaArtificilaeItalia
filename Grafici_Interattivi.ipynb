# %% [markdown]
# <a href="https://colab.research.google.com/github/IntelligenzaArtificilaeItalia/IntelligenzaArtificilaeItalia/blob/main/Grafici_Interattivi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading in the data
nifty_data = pd.read_csv('/content/drive/MyDrive/NIFTY_data_2020.csv',parse_dates=["Date"],index_col='Date')
nifty_data.head()
# Out:
#             NIFTY Bank index  ...  NIFTY Pharma index
# Date                          ...
# 2020-01-01          32102.90  ...             8047.10
# 2020-01-02          32443.85  ...             8053.95
# 2020-01-03          32069.25  ...             8111.95
# 2020-01-06          31237.15  ...             7987.35
# 2020-01-07          31399.40  ...             8036.50
#
# [5 rows x 4 columns]

# %%
nifty_data_resample = nifty_data.resample(rule = 'M').mean()
nifty_data_resample

# %%
nifty_data.plot(title='Nifty Index values in 2020', xlabel = 'Values',  figsize=(10,6) );

# %%
nifty_data.plot(kind='scatter',
        x='NIFTY FMCG index', 
        y='NIFTY Bank index',
        title = 'Scatter Plot for NIFTY Index values in 2020',
        figsize=(10,6));

# %%
nifty_data[['NIFTY FMCG index','NIFTY Bank index']].plot(kind='hist',figsize=(9,6), bins=30);

# %%
nifty_data_resample.plot(kind='bar',figsize=(10,6));

# %%
nifty_data_resample.index=['Jan','Feb','March','Apr','May','June','July']
nifty_data_resample['NIFTY Bank index'].plot.pie(legend=False, figsize=(10,6),autopct='%.1f');

# %%
# !pip install pandas-bokeh

# %%
import pandas_bokeh

# %%
pandas_bokeh.output_notebook() # for embedding plots in Jupyter Notebooks.

# %%
nifty_data.plot_bokeh(kind='line') #equivalent to nifty_data.plot_bokeh.line()
# Out:
#   <div class="bk-root" id="4bdf14c4-3797-4b94-8c23-6a0d7001a4db" data-root-id="1002"></div>
# Figure(id='1002', ...)

# %%
nifty_data.plot_bokeh.scatter(x='NIFTY FMCG index', y='NIFTY Bank index');
# Out:
#   <div class="bk-root" id="c9dd3a2c-d52a-4a7a-92d0-e79b7b2676d9" data-root-id="1339"></div>

# %%
nifty_data[['NIFTY FMCG index','NIFTY Bank index']].plot_bokeh(kind='hist', bins=30);
# Out:
#   <div class="bk-root" id="399e9865-8d4c-4f2d-ab0f-0596eb2a9c49" data-root-id="1479"></div>

# %%
nifty_data_resample.plot_bokeh(kind='bar');
# Out:
#   <div class="bk-root" id="0d09ed46-390d-4449-a935-78531d9bb62b" data-root-id="1714"></div>

# %%
nifty_data_resample.plot_bokeh(kind='barh',stacked=True);
# Out:
#   <div class="bk-root" id="db54a248-292c-42fb-b587-b32af87590c7" data-root-id="1955"></div>

# %%
nifty_data_resample.index=['Jan','Feb','March','Apr','May','June','July']
nifty_data_resample.plot_bokeh.pie(y ='NIFTY Bank index')
# Out:
# __x__values_original
#   <div class="bk-root" id="bd0da91f-9d2d-423d-86a6-0f75e5db76ea" data-root-id="2201"></div>
# Figure(id='2201', ...)

# %%
nifty_data_resample.plot_bokeh.pie()
# Out:
# __x__values_original
#   <div class="bk-root" id="4abea32c-b30c-4dca-82b1-829bbc4f7c13" data-root-id="2413"></div>
# Figure(id='2413', ...)
